# %% [markdown]
# <a href="https://colab.research.google.com/github/Akash-beep-ai/AML-Experiment/blob/main/13_07_26_AMLLAB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np


study_hours = [2, 4, 6, 8]
attendance = [70, 80, 85, 90]
assignment_mark = [12, 15, 18, 20]
final_mark = [45, 60, 75, 90]


data = pd.DataFrame({
    'Study Hours': study_hours,
    'Attendance': attendance,
    'Assignment Mark': assignment_mark,
    'Final Mark': final_mark
})


X = data[['Study Hours', 'Attendance', 'Assignment Mark']]
y = data['Final Mark']


model = LinearRegression()
model.fit(X, y)


y_pred = model.predict(X)


mae = mean_absolute_error(y, y_pred)
mse = mean_squared_error(y, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y, y_pred)


print("Model trained successfully!")
print("Coefficients:", model.coef_)
print("Intercept:", model.intercept_)

print("\nPerformance Metrics:")
print("MAE :", round(mae, 4))
print("MSE :", round(mse, 4))
print("RMSE:", round(rmse, 4))
print("R² Score:", round(r2, 4))
# Out:
# Model trained successfully!
# Coefficients: [ 7.50000000e+00 -1.87647463e-15  3.26878641e-15]
# Intercept: 30.000000000000085
#
# Performance Metrics:
# MAE : 0.0
# MSE : 0.0
# RMSE: 0.0
# R² Score: 1.0
